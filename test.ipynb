# %%
# setting
from src.infer_node import InferNode
from src.actions import prepocess, action_funcs
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = 'gpt-4-0613'
q = 'A positive integer $n$ is nice if there is a positive integer $m$ with exactly four positive divisors (including $1$ and $m$) such that the sum of the four divisors is equal to $n.$ Find the sum of all the nice numbers in the set $\\{ 2010,2011,2012,\\dots,2019 \\}.$ Show that it is 2016.'
question, conditions = prepocess(q, model)
solver = InferNode(action_funcs, '', conditions, [], question, top_level=0, inf_level=0, model=model)
logger, out = solver.act_gen()
# Out:
# Action selection: classify.
# Action: classify (Level 0)
# Output: [  {   "Conditions": ["A positive integer $n$ is nice", "There is a positive integer $m$ with exactly four positive divisors (including $1$ and $m$)", "The sum of the four divisors is equal to $n$"],   "Goal": "Identify the characteristics of a 'nice' number"  },  {   "Conditions": ["The set of numbers to consider is $\\{ 2010,2011,2012,\\dots,2019 \\}$", "Identify the characteristics of a 'nice' number"],   "Goal": "Identify which numbers in the set are 'nice'"  },  {   "Conditions": ["The task is to find the sum of all the nice numbers in the given set", "Identify which numbers in the set are 'nice'"],   "Goal": "Calculate the sum of all the 'nice' numbers in the set"  },  {   "Conditions": ["The desired sum is 2016", "Calculate the sum of all the 'nice' numbers in the set"],   "Goal": "Verify that the sum of all the 'nice' numbers in the set is 2016"  } ]
# Action selection: derive.
# Action: derive (Level 1)
# ...
